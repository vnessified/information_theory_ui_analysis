# %% [markdown]
# ## Imports

# %%
from glob import glob
import json
import numpy as np
import pandas as pd
import PIL

from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
sns.set_style("dark", {'axes.grid' : False})
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Load & display app screenshot images

# %%
app_imgs = glob('combined/*.jpg')
print('Total app screenshot images: {0:,}'.format(len(app_imgs)))
app_imgs[:5]
# Out:
# Total app screenshot images: 72,219
# ['combined/9733.jpg',
#  'combined/14147.jpg',
#  'combined/52112.jpg',
#  'combined/63.jpg',
#  'combined/6400.jpg']

# %%
plt.rcParams['figure.figsize'] = (16.0, 12.0)
plt.subplots_adjust(wspace=0, hspace=.1)

for i, img in enumerate(np.random.choice(app_imgs, 10)):
    img = PIL.Image.open(img)
    plt.subplot(2, 5, i + 1) 
    plt.imshow(img); plt.axis('off')

# %% [markdown]
# ## App view hierarchy
# This is essentially the structure of the app's UI based on the android code. For the purposes of this project, it does not provide any additional information.

# %%
with open('combined/2.json', 'r') as f:
    app_img_data = json.load(f)

print(app_img_data.keys())
print()
print(app_img_data['activity']['root'].keys())
# Out:
# dict_keys(['activity_name', 'activity', 'is_keyboard_deployed', 'request_id'])
#
# dict_keys(['scrollable-horizontal', 'draw', 'ancestors', 'clickable', 'pressed', 'focusable', 'long-clickable', 'enabled', 'bounds', 'visibility', 'content-desc', 'rel-bounds', 'focused', 'selected', 'scrollable-vertical', 'children', 'adapter-view', 'abs-pos', 'pointer', 'class', 'visible-to-user'])

# %% [markdown]
# ## UI details
# Metadata about each UI screen.

# %%
ui_details = pd.read_csv('ui_details.csv')
ui_details.columns = [c.lower().replace(' ', '_') for c in ui_details.columns]
ui_details['filename'] = ui_details['ui_number'].map(lambda x: 'combined/' + str(x) + '.jpg')
ui_details.head()
# Out:
#    ui_number            app_package_name  interaction_trace_number  \
# 0          0  com.brc.PeriodTrackerDiary                         0
# 1          1  com.brc.PeriodTrackerDiary                         0
# 2          2        yong.app.videoeditor                         0
# 3          3        yong.app.videoeditor                         0
# 4          4        yong.app.videoeditor                         0
#
#    ui_number_in_trace        filename
# 0                  15  combined/0.jpg
# 1                 531  combined/1.jpg
# 2                 221  combined/2.jpg
# 3                1289  combined/3.jpg
# 4                 125  combined/4.jpg

# %%
print('Shape: {0}'.format(ui_details.shape))
print('Total app screenshot images: {0:,}'.format(len(ui_details.ui_number.value_counts())))
print('Length of ui_number equals length app_imgs: {0}'.format(len(ui_details.ui_number.value_counts()) == len(app_imgs)))
print('Unique app packages: {0:,}'.format(len(ui_details.app_package_name.value_counts())))
# Out:
# Shape: (72219, 5)
# Total app screenshot images: 72,219
# Length of ui_number equals length app_imgs: True
# Unique app packages: 9,772

# %% [markdown]
# #### App package frequency
# Repeat app package names exist as the data include screenshots of different states within the same app.

# %%
ui_details.app_package_name.value_counts().head(10)
# Out:
# com.lazada.android                    76
# com.fourtechnologies.mynetdiary.ad    73
# com.jet.jet.app                       72
# com.slacker.radio                     70
# com.fivemobile.thescore               70
# com.bigoven.android                   69
# com.talabat                           65
# com.jackthreads.android               64
# com.bravolang.spanish                 63
# com.mapmywalk.android2                62
# Name: app_package_name, dtype: int64

# %% [markdown]
# #### Interaction traces
# Each app has interaction traces which are comprised of a sequence of UIs captured as screenshots (essentially the flow of states a user experiences while using an app). Each app can have multiple traces, ie trace_0, trace_1, etc.

# %%
ui_details.interaction_trace_number.value_counts()
# Out:
# 0    62188
# 1     7520
# 2     2317
# 3      166
# 4       23
# 6        5
# Name: interaction_trace_number, dtype: int64

# %% [markdown]
# **`ui_number_in_trace`** refers to the given screenshot's particular order in any given interaction trace

# %%
len(ui_details.ui_number_in_trace.value_counts())
# Out:
# 5533

# %% [markdown]
# #### Display UIs with associated app package name to verify they match
# Resize images for more convenient display and remove images that can't be opened with PIL

# %%
def img_resizer(filepath, new_width, new_height):
    img = PIL.Image.open(filepath)
    size = img.size
    if size[0] < size[1]:
        new_height = int(round(new_width * size[1] / size[0]))
        img_resized = img.resize((new_width, new_height), PIL.Image.ANTIALIAS)
    else:
        new_width = int(round(new_height * size[1] / size[0]))
        img_resized = img.resize((new_width, new_height), PIL.Image.ANTIALIAS)
    return img_resized

def img_validator(images):
    # this is slooooow
    corrupt_img_idx = []
    for i, x in enumerate(images):
        try:
            o = PIL.Image.open(x)
        except OSError as e:
            corrupt_img_idx.append(i)
            pass
    return corrupt_img_idx

# %%
corrupt_img_idx = img_validator(ui_details.filename)

# %%
ui_details.iloc[corrupt_img_idx]
# Out:
#        ui_number             app_package_name  interaction_trace_number  \
# 33103      33103                 org.msq.Face                         0
# 50116      50116  com.cmgdigital.wsbtvhandset                         0
# 63677      63677     com.glow.android.nurture                         0
#
#        ui_number_in_trace            filename
# 33103                 505  combined/33103.jpg
# 50116                1203  combined/50116.jpg
# 63677                 292  combined/63677.jpg

# %%
ui_details.drop(corrupt_img_idx, inplace=True)
ui_details.shape
# Out:
# (72216, 5)

# %% [markdown]
# 5 randomly selected UIs + app package names below:

# %%
random_idx = ui_details.sample(n=5, replace=False).index.values
for i in random_idx:
    print('App package name: {0}'.format(ui_details.app_package_name[i]))
    display(img_resizer(ui_details.filename[i], 200, 200))
    print('-------------------------------------------')
# Out:
# App package name: com.makru.minecraftbook
# <PIL.Image.Image image mode=RGB size=200x356 at 0x115E2A278>
# -------------------------------------------
# App package name: com.unearby.sayhi
# <PIL.Image.Image image mode=RGB size=200x356 at 0x115E2A278>
# -------------------------------------------
# App package name: com.cy.wifikey
# <PIL.Image.Image image mode=RGB size=200x356 at 0x115E2A278>
# -------------------------------------------
# App package name: com.osmino.wifispot
# <PIL.Image.Image image mode=RGB size=200x356 at 0x115E2A278>
# -------------------------------------------
# App package name: com.quickface.swipeforfacebook
# <PIL.Image.Image image mode=RGB size=200x356 at 0x115E2A278>
# -------------------------------------------

# %% [markdown]
# ## App details: android play store metadata
# Contains metadata about the apps in the dataset including an app’s category, average rating, number of ratings, and number of downloads. Unclear what "average rating" actually represents.

# %%
app_details = pd.read_csv('app_details.csv')
app_details.reset_index(level=0, inplace=True)
app_details.rename(columns = {'index':'App Package Name',
                              'App Package Name':'app name',
                              'Category':'star rating',
                              'Play Store Name': 'app category'}, inplace = True)
app_details.rename(columns = {}, inplace = True)
app_details.columns = [c.lower().replace(' ', '_') for c in app_details.columns]
app_details.head()
# Out:
#                           app_package_name                        app_name  \
# 0                    com.guideme.movieboxa    New Movie?Box Show Reference
# 1                     com.aon.mangaareader                   Mangaa Reader
# 2                          com.diaohs.cola  Eye Filter (Blue light filter)
# 3          com.pinnatta.android.api.fbmess          Pinnatta for Messenger
# 4  com.digidust.elokence.akinator.freemium         Akinator the Genie FREE
#
#         app_category  star_rating  average_rating  \
# 0  Books & Reference          3.2              83
# 1             Comics          4.0             686
# 2   Health & Fitness          4.6            2606
# 3             Social          4.3            6724
# 4      Entertainment          4.3         1171971
#
#               number_of_ratings  number_of_downloads
# 0             10,000 - 50,000                    NaN
# 1             10,000 - 50,000                    NaN
# 2           100,000 - 500,000                    NaN
# 3           100,000 - 500,000                    NaN
# 4    50,000,000 - 100,000,000                    NaN

# %%
app_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18814 entries, 0 to 18813
# Data columns (total 7 columns):
# app_package_name       18814 non-null object
# app_name               18814 non-null object
# app_category           18814 non-null object
# star_rating            18814 non-null float64
# average_rating         18814 non-null int64
# number_of_ratings      18814 non-null object
# number_of_downloads    0 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# #### Drop `number_of_downloads` as it contains no info

# %%
app_details.drop(['number_of_downloads'], axis=1, inplace=True)

# %% [markdown]
# #### Explore `app_package_names` and `app_name `

# %%
print('Shape: {0}'.format(app_details.shape))
print('Unique app names: {0:,}'.format(len(app_details.app_name.value_counts())))
print('Unique app packages: {0:,}'.format(len(app_details.app_package_name.value_counts())))
print('Num of ui_details.app_package_name equals app_details.app_package_name: \n{0}'.format(len(ui_details.app_package_name.value_counts()) == len(app_details.app_package_name.value_counts())))
# Out:
# Shape: (18814, 6)
# Unique app names: 11,062
# Unique app packages: 10,954
# Num of ui_details.app_package_name equals app_details.app_package_name:
# False

# %% [markdown]
# #### Some apps share app name but have a different app package name
# What this means: more general/utility type apps will often have generic names but are created by different developers.

# %%
app_details.app_name.value_counts().head()
# Out:
# Music Player                  20
# Weather                       15
# ????                          14
# Spanish English Translator    14
# Voice Changer                 12
# Name: app_name, dtype: int64

# %%
app_details[app_details.app_name == 'Music Player'].head()
# Out:
#                              app_package_name      app_name   app_category  \
# 2689  music.search.player.mp3player.cut.music  Music Player  Music & Audio
# 3951                      com.jrtstudio.music  Music Player  Music & Audio
# 5206            media.audioplayer.musicplayer  Music Player  Music & Audio
# 6411              com.zentertain.music.player  Music Player  Music & Audio
# 7511             com.fotoable.mp3.musicplayer  Music Player  Music & Audio
#
#       star_rating  average_rating            number_of_ratings
# 2689          4.2           76107     5,000,000 - 10,000,000
# 3951          3.9          219762    10,000,000 - 50,000,000
# 5206          4.4          672634    10,000,000 - 50,000,000
# 6411          4.3           33664      1,000,000 - 5,000,000
# 7511          4.1            8415        500,000 - 1,000,000

# %% [markdown]
# #### Duplicate app package names
# Appears as though app package names have duplicate entries, however they do differ on average rating.

# %%
app_details.app_package_name.value_counts().head()
# Out:
# air.com.A3dtuning.Tuning3D    4
# net.flixster.android          4
# com.microsoft.smartglass      4
# com.adpog.diary               4
# it.medieval.blueftp           4
# Name: app_package_name, dtype: int64

# %%
app_details[app_details.app_package_name == 'air.com.A3dtuning.Tuning3D'].head()
# Out:
#                  app_package_name  app_name   app_category  star_rating  \
# 7867   air.com.A3dtuning.Tuning3D  3DTuning  Entertainment          4.2
# 12799  air.com.A3dtuning.Tuning3D  3DTuning  Entertainment          4.2
# 17901  air.com.A3dtuning.Tuning3D  3DTuning  Entertainment          4.2
# 18789  air.com.A3dtuning.Tuning3D  3DTuning  Entertainment          4.2
#
#        average_rating           number_of_ratings
# 7867           155394    5,000,000 - 10,000,000
# 12799          155265    5,000,000 - 10,000,000
# 17901          165518    5,000,000 - 10,000,000
# 18789          155394    5,000,000 - 10,000,000

# %%
app_details.app_category.value_counts(ascending=True).plot.bar(figsize=(8,4)).set_ylabel('Number of Apps');

# %%
len(app_details.app_category.value_counts())
# Out:
# 28

# %%
app_details[app_details.app_category == 'Productivity']
# Out:
#       app_package_name                       app_name  app_category  \
# 18795  com.sftx.repost  Repost for Instagram RepostIt  Productivity
#
#        star_rating  average_rating          number_of_ratings
# 18795          4.1           25836    1,000,000 - 5,000,000

# %%
app_details[app_details.app_category == 'Entertainment'].sort_values(by='star_rating', ascending=False).head()
# Out:
#                               app_package_name  \
# 15352  com.crocusgames.destinyinventorymanager
# 9220                           com.jy.vplayer2
# 11286                          com.zpt.appgift
# 18345                          com.jy.vplayer2
# 18119                          com.zpt.appgift
#
#                              app_name   app_category  star_rating  \
# 15352  Vault Item Manager for Destiny  Entertainment          4.8
# 9220   VSounds - Vine Soundboard Free  Entertainment          4.8
# 11286     Cash Gift - Free Gift Cards  Entertainment          4.8
# 18345  VSounds - Vine Soundboard Free  Entertainment          4.8
# 18119     Cash Gift - Free Gift Cards  Entertainment          4.8
#
#        average_rating          number_of_ratings
# 15352            1335          10,000 - 50,000
# 9220           181790    1,000,000 - 5,000,000
# 11286          215295    1,000,000 - 5,000,000
# 18345          181804    1,000,000 - 5,000,000
# 18119          215317    1,000,000 - 5,000,000

# %%
app_details.groupby('star_rating')['star_rating'].count().plot.bar(figsize=(8,4)).set_ylabel('Number of Ratings');

# %%
app_details.groupby('app_category')['star_rating'].mean().sort_values().plot.bar(figsize=(8,4)).set_ylabel('Number of Ratings');

# %%
app_details.groupby('app_category')['average_rating'].mean().sort_values().plot.bar(figsize=(8,4)).set_ylabel('Number of Ratings');

# %%
app_details.groupby('app_category')['average_rating'].mean().head()
# Out:
# app_category
# Art & Design         27937.335443
# Auto & Vehicles      13553.356164
# Beauty               20025.004785
# Books & Reference    72607.655704
# Business             40064.977461
# Name: average_rating, dtype: float64

# %%
app_details.number_of_ratings.value_counts(ascending=True).plot.bar(figsize=(8,4)).set_ylabel('Number of Ratings');

# %%
app_details.number_of_ratings.value_counts()
# Out:
#   1,000,000 - 5,000,000              5887
#   100,000 - 500,000                  3833
#   500,000 - 1,000,000                2243
#   10,000 - 50,000                    1653
#   50,000 - 100,000                   1561
#   5,000,000 - 10,000,000             1501
#   10,000,000 - 50,000,000            1379
#   5,000 - 10,000                      201
#   50,000,000 - 100,000,000            194
#   100,000,000 - 500,000,000           150
#   1,000 - 5,000                       132
#   1,000,000,000 - 5,000,000,000        49
#   500,000,000 - 1,000,000,000          18
#   500 - 1,000                           7
#   100 - 500                             6
# Name: number_of_ratings, dtype: int64

# %% [markdown]
# #### Drop rows with 5,000 or less ratings

# %%
def min_ratings(x):
    new_str = x.replace(',','').replace(' ','').replace('-',',')
    return min(list(map(int, new_str.split(','))))

# %%
app_details['min_ratings'] = app_details.number_of_ratings.map(lambda x: min_ratings(x))

# %%
app_details[app_details.min_ratings <= 5000].shape
# Out:
# (346, 7)

# %%
app_details.drop(app_details[app_details.min_ratings <= 5000].index, inplace=True)

# %%
app_details.shape
# Out:
# (18468, 7)

# %% [markdown]
# ## Merge ui_details and app_details dataframes
# #### Groupby `app_package_name` to generate dataframe of unique app packages from `ui_details` dataframe
# Capture `ui_number`, `interaction_trace_number`, `ui_number_in_trace`, and `filename` in groupby.

# %%
d1 = {'ui_number': lambda x: list(set(x)),
     'interaction_trace_number': lambda x: list(set(x)),
     'ui_number_in_trace': lambda x: list(set(x)),
     'filename': lambda x: list(set(x))}


ui_details_agg = ui_details.groupby('app_package_name').agg(d1)
ui_details_agg.reset_index(inplace=True)
ui_details_agg.head()
# Out:
#              app_package_name  \
# 0  B4A.BigFivePersonalityTest
# 1        CN.MyPrivateMessages
# 2              DOCECG2.doctor
# 3   Gecko.Droid.PhysicsHelper
# 4          HinKhoj.Dictionary
#
#                                            ui_number interaction_trace_number  \
# 0                                            [49783]                      [0]
# 1                                            [26083]                      [0]
# 2                                            [51036]                      [0]
# 3                [29868, 29869, 21237, 21238, 21239]                   [0, 2]
# 4  [42080, 42081, 42082, 42083, 42084, 42085, 420...                      [1]
#
#                                   ui_number_in_trace  \
# 0                                              [221]
# 1                                               [15]
# 2                                               [58]
# 3                         [194, 269, 1361, 370, 285]
# 4  [864, 324, 741, 710, 132, 261, 876, 972, 654, ...
#
#                                             filename
# 0                               [combined/49783.jpg]
# 1                               [combined/26083.jpg]
# 2                               [combined/51036.jpg]
# 3  [combined/29868.jpg, combined/21238.jpg, combi...
# 4  [combined/42082.jpg, combined/42084.jpg, combi...

# %% [markdown]
# #### Again groupby `app_package_name` to generate dataframe of unique names in `app_details` dataframe
# Capture app name, app category, star_rating, average_rating, and number of ratings as lists in groupby.

# %%
d2 = {'app_name': lambda x: list(set(x)),
     'app_category': lambda x: list(set(x)),
     'star_rating': lambda x: list(set(x)),
     'average_rating': lambda x: list(set(x)),
     'number_of_ratings': lambda x: list(set(x)),
     'min_ratings': lambda x: list(set(x))}


app_details_agg = app_details.groupby('app_package_name').agg(d2)
app_details_agg.reset_index(inplace=True)
app_details_agg.head()
# Out:
#              app_package_name                         app_name  \
# 0  B4A.BigFivePersonalityTest         [Big 5 Personality Test]
# 1        CN.MyPrivateMessages                     [Calculator]
# 2                  Cam.SILENT  [Uva Silent Widget Camera Free]
# 3              DOCECG2.doctor    [Electrocardiogram ECG Types]
# 4   Gecko.Droid.PhysicsHelper                 [Pocket Physics]
#
#                 app_category star_rating         average_rating  \
# 0                [Education]       [3.6]                 [6698]
# 1            [Communication]       [4.3]  [17020, 16918, 16919]
# 2  [Video Players & Editors]       [3.9]                 [9616]
# 3                  [Medical]       [3.9]           [4134, 4135]
# 4                [Education]       [4.1]                [15938]
#
#               number_of_ratings min_ratings
# 0   [  1,000,000 - 5,000,000  ]   [1000000]
# 1   [  1,000,000 - 5,000,000  ]   [1000000]
# 2  [  5,000,000 - 10,000,000  ]   [5000000]
# 3     [  500,000 - 1,000,000  ]    [500000]
# 4   [  1,000,000 - 5,000,000  ]   [1000000]

# %% [markdown]
# #### Find intersection of `app_package_name` for both dataframes

# %%
app_details_agg.app_package_name.shape, ui_details_agg.app_package_name.shape
# Out:
# ((10806,), (9771,))

# %%
app_details_agg.app_package_name.isin(ui_details_agg.app_package_name).value_counts()
# Out:
# True     9620
# False    1186
# Name: app_package_name, dtype: int64

# %%
ui_details_agg.app_package_name.isin(app_details_agg.app_package_name).value_counts()
# Out:
# True     9620
# False     151
# Name: app_package_name, dtype: int64

# %% [markdown]
# Verify `isin` results

# %%
app_details_agg_lst = app_details_agg.app_package_name.values.tolist()
ui_details_agg_lst = ui_details_agg.app_package_name.values.tolist()

print(len([i for i in app_details_agg_lst if i not in ui_details_agg_lst]))
print(len([i for i in ui_details_agg_lst if i not in app_details_agg_lst]))

print(len(set(app_details_agg_lst).intersection(ui_details_agg_lst)))
print(len(set(ui_details_agg_lst).intersection(app_details_agg_lst)))
# Out:
# 1186
# 151
# 9620
# 9620

# %% [markdown]
# #### Inner join both dataframes with `pd.merge`

# %%
result = pd.merge(app_details_agg, ui_details_agg, on='app_package_name')
result.head()
# Out:
#              app_package_name                       app_name  \
# 0  B4A.BigFivePersonalityTest       [Big 5 Personality Test]
# 1        CN.MyPrivateMessages                   [Calculator]
# 2              DOCECG2.doctor  [Electrocardiogram ECG Types]
# 3   Gecko.Droid.PhysicsHelper               [Pocket Physics]
# 4          HinKhoj.Dictionary     [English Hindi Dictionary]
#
#           app_category star_rating         average_rating  \
# 0          [Education]       [3.6]                 [6698]
# 1      [Communication]       [4.3]  [17020, 16918, 16919]
# 2            [Medical]       [3.9]           [4134, 4135]
# 3          [Education]       [4.1]                [15938]
# 4  [Books & Reference]       [4.3]       [246778, 247420]
#
#                number_of_ratings min_ratings  \
# 0    [  1,000,000 - 5,000,000  ]   [1000000]
# 1    [  1,000,000 - 5,000,000  ]   [1000000]
# 2      [  500,000 - 1,000,000  ]    [500000]
# 3    [  1,000,000 - 5,000,000  ]   [1000000]
# 4  [  10,000,000 - 50,000,000  ]  [10000000]
#
#                                            ui_number interaction_trace_number  \
# 0                                            [49783]                      [0]
# 1                                            [26083]                      [0]
# 2                                            [51036]                      [0]
# 3                [29868, 29869, 21237, 21238, 21239]                   [0, 2]
# 4  [42080, 42081, 42082, 42083, 42084, 42085, 420...                      [1]
#
#                                   ui_number_in_trace  \
# 0                                              [221]
# 1                                               [15]
# 2                                               [58]
# 3                         [194, 269, 1361, 370, 285]
# 4  [864, 324, 741, 710, 132, 261, 876, 972, 654, ...
#
#                                             filename
# 0                               [combined/49783.jpg]
# 1                               [combined/26083.jpg]
# 2                               [combined/51036.jpg]
# 3  [combined/29868.jpg, combined/21238.jpg, combi...
# 4  [combined/42082.jpg, combined/42084.jpg, combi...

# %%
print(result.shape)
# Out:
# (9620, 11)

# %% [markdown]
# #### Save resulting dataframe
# Use `df.to_pickle` to prevent list data structure in dataframe being converted to a string encapsulated list.

# %%
result.to_pickle('merged_data/app_ui_df.pkl')

# %% [markdown]
# ## More data munging

# %% [markdown]
# #### Load data

# %%
app_ui_df = pd.read_pickle('merged_data/app_ui_df.pkl')
print(app_ui_df.shape)
app_ui_df.head()
# Out:
# (9620, 11)
#              app_package_name                       app_name  \
# 0  B4A.BigFivePersonalityTest       [Big 5 Personality Test]
# 1        CN.MyPrivateMessages                   [Calculator]
# 2              DOCECG2.doctor  [Electrocardiogram ECG Types]
# 3   Gecko.Droid.PhysicsHelper               [Pocket Physics]
# 4          HinKhoj.Dictionary     [English Hindi Dictionary]
#
#           app_category star_rating         average_rating  \
# 0          [Education]       [3.6]                 [6698]
# 1      [Communication]       [4.3]  [17020, 16918, 16919]
# 2            [Medical]       [3.9]           [4134, 4135]
# 3          [Education]       [4.1]                [15938]
# 4  [Books & Reference]       [4.3]       [246778, 247420]
#
#                number_of_ratings min_ratings  \
# 0    [  1,000,000 - 5,000,000  ]   [1000000]
# 1    [  1,000,000 - 5,000,000  ]   [1000000]
# 2      [  500,000 - 1,000,000  ]    [500000]
# 3    [  1,000,000 - 5,000,000  ]   [1000000]
# 4  [  10,000,000 - 50,000,000  ]  [10000000]
#
#                                            ui_number interaction_trace_number  \
# 0                                            [49783]                      [0]
# 1                                            [26083]                      [0]
# 2                                            [51036]                      [0]
# 3                [29868, 29869, 21237, 21238, 21239]                   [0, 2]
# 4  [42080, 42081, 42082, 42083, 42084, 42085, 420...                      [1]
#
#                                   ui_number_in_trace  \
# 0                                              [221]
# 1                                               [15]
# 2                                               [58]
# 3                         [194, 269, 1361, 370, 285]
# 4  [864, 324, 741, 710, 132, 261, 876, 972, 654, ...
#
#                                             filename
# 0                               [combined/49783.jpg]
# 1                               [combined/26083.jpg]
# 2                               [combined/51036.jpg]
# 3  [combined/29868.jpg, combined/21238.jpg, combi...
# 4  [combined/42082.jpg, combined/42084.jpg, combi...

# %%
len(app_ui_df.app_package_name.value_counts())
# Out:
# 9620

# %% [markdown]
# #### App packages that have multiple app names

# %%
app_ui_df.app_name.map(lambda x: len(x)).value_counts()
# Out:
# 1    9290
# 2     330
# Name: app_name, dtype: int64

# %%
app_ui_df[app_ui_df.app_name.map(lambda x: len(x)) > 1].head()
# Out:
#                                 app_package_name  \
# 20                                  air.Chat.org
# 51                          air.com.flaxbin.chat
# 95   air.net.thedigitalsits.molfar.prankcalldial
# 121                                      and.p2l
# 142                               app.hurdlr.com
#
#                                               app_name     app_category  \
# 20     [Video Chat Rooms, Video Chat Rooms - Look2cam]         [Social]
# 51   [ChatVideo - Free Video Chat, ChatVideo ? Meet...         [Dating]
# 95   [Prankster - Prank Call App, Prankster - the P...  [Entertainment]
# 121  [Phone 2 Location - Caller Id, Mobile Phone Nu...  [Communication]
# 142  [Hurdlr for Drivers, Hurdlr - 1099 Taxes & Mil...       [Business]
#
#     star_rating                average_rating  \
# 20        [4.0]                [16824, 16116]
# 51        [4.1]                [37440, 44854]
# 95   [4.4, 4.3]                [23516, 11868]
# 121       [4.1]  [83320, 83338, 83339, 83949]
# 142  [4.7, 4.6]                  [1121, 1515]
#
#                                     number_of_ratings       min_ratings  \
# 20                        [  1,000,000 - 5,000,000  ]         [1000000]
# 51                        [  1,000,000 - 5,000,000  ]         [1000000]
# 95   [  500,000 - 1,000,000  ,   100,000 - 500,000  ]  [100000, 500000]
# 121                      [  5,000,000 - 10,000,000  ]         [5000000]
# 142                            [  50,000 - 100,000  ]           [50000]
#
#                  ui_number interaction_trace_number    ui_number_in_trace  \
# 20                 [20513]                      [2]                  [15]
# 51   [69434, 69435, 69436]                      [0]      [130, 334, 1543]
# 95          [30017, 30018]                      [0]              [62, 63]
# 121                [12294]                      [0]                 [101]
# 142   [506, 507, 508, 509]                      [0]  [505, 331, 611, 305]
#
#                                               filename
# 20                                [combined/20513.jpg]
# 51   [combined/69434.jpg, combined/69436.jpg, combi...
# 95            [combined/30017.jpg, combined/30018.jpg]
# 121                               [combined/12294.jpg]
# 142  [combined/507.jpg, combined/508.jpg, combined/...

# %% [markdown]
# #### App packages that have multiple app categories

# %%
app_ui_df.app_category.map(lambda x: len(x)).value_counts()
# Out:
# 1    9567
# 2      53
# Name: app_category, dtype: int64

# %%
app_ui_df[app_ui_df.app_category.map(lambda x: len(x)) > 1].head()
# Out:
#                          app_package_name                          app_name  \
# 321                       co.bikecomputer                   [Bike Computer]
# 327                      co.clover.clover               [Clover Dating App]
# 663          com.affinity.dallas_football  [Dallas Football Louder Rewards]
# 665      com.affinity.pittsburgh_football     [Pittsburgh Football Rewards]
# 797  com.amrelmadah.freelancing.zawagalan               [Marriage Mediator]
#
#                    app_category star_rating average_rating  \
# 321  [Sports, Health & Fitness]  [4.6, 4.5]    [2121, 340]
# 327            [Dating, Social]  [4.1, 4.0]   [3442, 5743]
# 663            [Social, Sports]       [4.5]   [6952, 7739]
# 665            [Social, Sports]       [4.4]   [3537, 3876]
# 797            [Dating, Social]  [4.0, 4.1]     [622, 350]
#
#                                  number_of_ratings      min_ratings  \
# 321   [  10,000 - 50,000  ,   100,000 - 500,000  ]  [10000, 100000]
# 327                        [  100,000 - 500,000  ]         [100000]
# 663                        [  100,000 - 500,000  ]         [100000]
# 665                        [  100,000 - 500,000  ]         [100000]
# 797  [  50,000 - 100,000  ,   100,000 - 500,000  ]  [50000, 100000]
#
#                                              ui_number  \
# 321               [9475, 9476, 9477, 9478, 9479, 9480]
# 327                [55475, 55476, 55477, 55478, 55479]
# 663                                     [64424, 60945]
# 665                                     [24586, 61135]
# 797  [11136, 11137, 11138, 11139, 11140, 11141, 111...
#
#     interaction_trace_number  \
# 321                      [0]
# 327                      [0]
# 663                   [1, 2]
# 665                   [0, 2]
# 797                      [0]
#
#                                     ui_number_in_trace  \
# 321                         [69, 17, 116, 125, 61, 30]
# 327                         [429, 118, 1174, 854, 825]
# 663                                          [72, 287]
# 665                                           [2, 127]
# 797  [1152, 900, 1191, 775, 1193, 656, 1265, 1234, ...
#
#                                               filename
# 321  [combined/9475.jpg, combined/9477.jpg, combine...
# 327  [combined/55476.jpg, combined/55479.jpg, combi...
# 663           [combined/60945.jpg, combined/64424.jpg]
# 665           [combined/61135.jpg, combined/24586.jpg]
# 797  [combined/11134.jpg, combined/11140.jpg, combi...

# %% [markdown]
# #### App packages that have multiple app names AND categories

# %%
print(app_ui_df[(app_ui_df.app_name.map(lambda x: len(x)) > 1) & (app_ui_df.app_category.map(lambda x: len(x)) > 1)].shape)
app_ui_df[(app_ui_df.app_name.map(lambda x: len(x)) > 1) & (app_ui_df.app_category.map(lambda x: len(x)) > 1)].head()
# Out:
# (8, 11)
#                 app_package_name  \
# 1839  com.cliqs.love.romance.sms
# 2795                com.fitradio
# 3666     com.ilocatemobile.track
# 3681             com.imp.hoorray
# 3687           com.inapp.incolor
#
#                                                app_name  \
# 1839  [5000+ Love Messages Love SMS, 5000+ Love Mess...
# 2795  [FIT Radio Workout Music, FitRadio Workout Mus...
# 3666  [Track Any Phone -ilocateMobile, Track Any Pho...
# 3681                 [My Great Recipes, MyGreatRecipes]
# 3687  [InColor - Coloring Book, Incolor - Coloring B...
#
#                            app_category star_rating      average_rating  \
# 1839            [Social, Communication]       [4.2]      [20112, 19325]
# 2795  [Music & Audio, Health & Fitness]       [4.2]      [10519, 10167]
# 3666                [Lifestyle, Social]       [3.7]  [9281, 7889, 7871]
# 3681          [Lifestyle, Food & Drink]       [4.4]          [389, 318]
# 3687      [Entertainment, Art & Design]  [4.4, 4.6]       [16894, 2231]
#
#                                       number_of_ratings        min_ratings  \
# 1839                        [  1,000,000 - 5,000,000  ]          [1000000]
# 2795  [  500,000 - 1,000,000  ,   1,000,000 - 5,000,...  [500000, 1000000]
# 3666                        [  1,000,000 - 5,000,000  ]          [1000000]
# 3681                             [  50,000 - 100,000  ]            [50000]
# 3687   [  500,000 - 1,000,000  ,   100,000 - 500,000  ]   [100000, 500000]
#
#                                               ui_number  \
# 1839                                    [451, 452, 453]
# 2795  [38433, 38434, 38435, 38436, 38437, 38438, 384...
# 3666                                            [19900]
# 3681                              [69416, 69417, 69415]
# 3687  [61152, 61153, 61154, 61155, 61156, 61157, 611...
#
#      interaction_trace_number  \
# 1839                      [0]
# 2795                      [0]
# 3666                      [0]
# 3681                      [0]
# 3687                      [0]
#
#                                      ui_number_in_trace  \
# 1839                                      [26, 204, 62]
# 2795  [3, 132, 807, 811, 172, 141, 12, 786, 53, 822,...
# 3666                                             [1235]
# 3681                                      [107, 94, 22]
# 3687  [512, 513, 66, 196, 165, 5, 37, 73, 12, 142, 1...
#
#                                                filename
# 1839  [combined/451.jpg, combined/452.jpg, combined/...
# 2795  [combined/38437.jpg, combined/38435.jpg, combi...
# 3666                               [combined/19900.jpg]
# 3681  [combined/69415.jpg, combined/69416.jpg, combi...
# 3687  [combined/61144.jpg, combined/61146.jpg, combi...

# %% [markdown]
# #### Drop rows with multiple app categories
# To make things cleaner — only 53 rows

# %%
app_ui_df.drop(app_ui_df[app_ui_df.app_category.map(lambda x: len(x)) > 1].index, inplace=True)

# %%
app_ui_df.shape
# Out:
# (9567, 11)

# %%
app_ui_df['app_category'] = app_ui_df.app_category.map(lambda x: x[0])

# %% [markdown]
# #### App packages that have multiple star ratings

# %%
app_ui_df.star_rating.map(lambda x: len(x)).value_counts()
# Out:
# 1    8259
# 2    1308
# Name: star_rating, dtype: int64

# %%
app_ui_df[app_ui_df.star_rating.map(lambda x: len(x)) > 1].head()
# Out:
#                        app_package_name                          app_name  \
# 9              SavySoda.PrivateBrowsing    [Full Screen Private Browsing]
# 21                 air.FootballDoodFree                   [Football Dood]
# 31   air.bahraniapps.comicspanelcreator            [Comics Panel Creator]
# 36  air.cbn.superbook.bible.app.android  [Superbook Bible, Video & Games]
# 39   air.com.KalromSystems.SandDrawLite   [Sand Draw Sketch: Drawing Pad]
#
#      app_category star_rating         average_rating  \
# 9   Communication  [3.8, 3.7]           [1537, 1495]
# 21         Sports  [3.7, 3.8]           [1122, 1147]
# 31         Comics  [3.5, 3.4]             [297, 253]
# 36      Education  [4.7, 4.8]         [72513, 60571]
# 39   Art & Design  [4.0, 4.2]  [45507, 33797, 33695]
#
#               number_of_ratings min_ratings  \
# 9       [  100,000 - 500,000  ]    [100000]
# 21      [  100,000 - 500,000  ]    [100000]
# 31        [  10,000 - 50,000  ]     [10000]
# 36  [  1,000,000 - 5,000,000  ]   [1000000]
# 39  [  1,000,000 - 5,000,000  ]   [1000000]
#
#                                             ui_number  \
# 9   [38944, 38945, 38946, 38947, 38948, 57785, 57786]
# 21                              [46752, 46753, 46754]
# 31                              [23192, 23190, 23191]
# 36                                            [57834]
# 39                                            [50670]
#
#    interaction_trace_number                 ui_number_in_trace  \
# 9                    [0, 1]  [129, 3, 196, 138, 107, 177, 117]
# 21                      [0]                      [1, 189, 142]
# 31                      [0]                    [768, 932, 432]
# 36                      [0]                              [125]
# 39                      [0]                             [1640]
#
#                                              filename
# 9   [combined/38944.jpg, combined/57786.jpg, combi...
# 21  [combined/46752.jpg, combined/46754.jpg, combi...
# 31  [combined/23190.jpg, combined/23191.jpg, combi...
# 36                               [combined/57834.jpg]
# 39                               [combined/50670.jpg]

# %% [markdown]
# #### App packages that have multiple average ratings

# %%
app_ui_df.average_rating.map(lambda x: len(x)).value_counts()
# Out:
# 1    4823
# 2    3093
# 3    1432
# 4     219
# Name: average_rating, dtype: int64

# %%
app_ui_df[app_ui_df.average_rating.map(lambda x: len(x)) > 1].head()
# Out:
#            app_package_name                        app_name  \
# 1      CN.MyPrivateMessages                    [Calculator]
# 2            DOCECG2.doctor   [Electrocardiogram ECG Types]
# 4        HinKhoj.Dictionary      [English Hindi Dictionary]
# 5            Kal.FlightInfo                    [Korean Air]
# 9  SavySoda.PrivateBrowsing  [Full Screen Private Browsing]
#
#         app_category star_rating         average_rating  \
# 1      Communication       [4.3]  [17020, 16918, 16919]
# 2            Medical       [3.9]           [4134, 4135]
# 4  Books & Reference       [4.3]       [246778, 247420]
# 5     Travel & Local       [3.0]     [7049, 7083, 7145]
# 9      Communication  [3.8, 3.7]           [1537, 1495]
#
#                number_of_ratings min_ratings  \
# 1    [  1,000,000 - 5,000,000  ]   [1000000]
# 2      [  500,000 - 1,000,000  ]    [500000]
# 4  [  10,000,000 - 50,000,000  ]  [10000000]
# 5    [  1,000,000 - 5,000,000  ]   [1000000]
# 9        [  100,000 - 500,000  ]    [100000]
#
#                                            ui_number interaction_trace_number  \
# 1                                            [26083]                      [0]
# 2                                            [51036]                      [0]
# 4  [42080, 42081, 42082, 42083, 42084, 42085, 420...                      [1]
# 5                              [57784, 57782, 57783]                      [0]
# 9  [38944, 38945, 38946, 38947, 38948, 57785, 57786]                   [0, 1]
#
#                                   ui_number_in_trace  \
# 1                                               [15]
# 2                                               [58]
# 4  [864, 324, 741, 710, 132, 261, 876, 972, 654, ...
# 5                                      [272, 2, 228]
# 9                  [129, 3, 196, 138, 107, 177, 117]
#
#                                             filename
# 1                               [combined/26083.jpg]
# 2                               [combined/51036.jpg]
# 4  [combined/42082.jpg, combined/42084.jpg, combi...
# 5  [combined/57782.jpg, combined/57783.jpg, combi...
# 9  [combined/38944.jpg, combined/57786.jpg, combi...

# %% [markdown]
# #### App packages that have multiple number of ratings

# %%
app_ui_df.number_of_ratings.map(lambda x: len(x)).value_counts()
# Out:
# 1    8685
# 2     882
# Name: number_of_ratings, dtype: int64

# %%
app_ui_df[app_ui_df.number_of_ratings.map(lambda x: len(x)) > 1].head()
# Out:
#                                    app_package_name  \
# 41                air.com.animangaplus.johnnytest01
# 43              air.com.animangaplus.totallyspies01
# 47  air.com.designersofcode.lovecraftcollectionvol1
# 71              air.com.nbcuni.com.telemundo.envivo
# 95      air.net.thedigitalsits.molfar.prankcalldial
#
#                                              app_name   app_category  \
# 41                            [Johnny Test: Johnny X]         Comics
# 43                                   [Totally Spies!]         Comics
# 47                    [Lovecraft Collection ? Vol. 1]         Comics
# 71                     [Telemundo Deportes - En Vivo]         Sports
# 95  [Prankster - Prank Call App, Prankster - the P...  Entertainment
#
#    star_rating  average_rating  \
# 41       [4.1]      [357, 486]
# 43       [4.0]    [2235, 1919]
# 47       [4.8]    [3596, 7870]
# 71  [4.2, 4.3]    [4889, 5003]
# 95  [4.4, 4.3]  [23516, 11868]
#
#                                    number_of_ratings       min_ratings  \
# 41       [  10,000 - 50,000  ,   50,000 - 100,000  ]    [10000, 50000]
# 43     [  50,000 - 100,000  ,   100,000 - 500,000  ]   [50000, 100000]
# 47      [  10,000 - 50,000  ,   100,000 - 500,000  ]   [10000, 100000]
# 71  [  500,000 - 1,000,000  ,   100,000 - 500,000  ]  [100000, 500000]
# 95  [  500,000 - 1,000,000  ,   100,000 - 500,000  ]  [100000, 500000]
#
#                                      ui_number interaction_trace_number  \
# 41                                     [17298]                      [0]
# 43                                     [41239]                      [0]
# 47                              [18915, 18916]                      [0]
# 71  [64041, 70349, 70350, 70351, 70352, 70353]                   [0, 1]
# 95                              [30017, 30018]                      [0]
#
#                ui_number_in_trace  \
# 41                           [14]
# 43                            [9]
# 47                      [3474, 3]
# 71  [1216, 740, 710, 6, 211, 446]
# 95                       [62, 63]
#
#                                              filename
# 41                               [combined/17298.jpg]
# 43                               [combined/41239.jpg]
# 47           [combined/18915.jpg, combined/18916.jpg]
# 71  [combined/70353.jpg, combined/70352.jpg, combi...
# 95           [combined/30017.jpg, combined/30018.jpg]

# %% [markdown]
# #### Subset dataframe to only columns of interest

# %%
app_ui_df['star_rating_ave'] = app_ui_df.star_rating.map(lambda x: np.mean(x))
app_ui_df['average_rating_ave'] = app_ui_df.average_rating.map(lambda x: np.mean(x))
app_ui_df['min_ratings_ave'] = app_ui_df.min_ratings.map(lambda x: np.mean(x))

# %%
cols_keep = ['app_package_name', 'app_name', 'app_category', 'star_rating_ave', 'average_rating_ave', 'min_ratings_ave', 'filename']

# %%
app_data_clean = app_ui_df[cols_keep]

# %% [markdown]
# #### Save as CSV

# %%
app_data.to_csv('merged_data/app_data_clean.csv', index=False)
